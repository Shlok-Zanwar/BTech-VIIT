# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('train.csv')
testset = pd.read_csv('test.csv')

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
# Taking all rows except id and price
X_train = dataset.iloc[:, 1:-1]
# Except id
X_test = testset.iloc[:, 1:]
# Price
y_train = dataset.iloc[:, -1]

# %%
print(X_train.head())
print(X_test.head())
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          60       RL         65.0  ...    2008       WD        Normal
# 1          20       RL         80.0  ...    2007       WD        Normal
# 2          60       RL         68.0  ...    2008       WD        Normal
# 3          70       RL         60.0  ...    2006       WD       Abnorml
# 4          60       RL         84.0  ...    2008       WD        Normal
#
# [5 rows x 79 columns]
#    MSSubClass MSZoning  LotFrontage  ...  YrSold SaleType SaleCondition
# 0          20       RH         80.0  ...    2010       WD        Normal
# 1          20       RL         81.0  ...    2010       WD        Normal
# 2          60       RL         74.0  ...    2010       WD        Normal
# 3          60       RL         78.0  ...    2010       WD        Normal
# 4         120       RL         43.0  ...    2010       WD        Normal
#
# [5 rows x 79 columns]

# %%
# Geiitng numeric and string columns
datasetCols = X_train.columns
numericCols = []
strCols = []
for col in datasetCols:
  if X_train[col].dtype == "int64" or X_train[col].dtype == "float64":
    numericCols.append(col)
  else:
    strCols.append(col)

# %%
X_train_num = pd.DataFrame(X_train, columns=numericCols)
X_train_str = pd.DataFrame(X_train, columns=strCols)
X_test_num = pd.DataFrame(X_test, columns=numericCols)
X_test_str = pd.DataFrame(X_test, columns=strCols)

# %%
print(X_train_num)
print(X_train_str)
print(X_test_num)
print(X_test_str)
# Out:
#       MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold
# 0             60         65.0     8450  ...        0       2    2008
# 1             20         80.0     9600  ...        0       5    2007
# 2             60         68.0    11250  ...        0       9    2008
# 3             70         60.0     9550  ...        0       2    2006
# 4             60         84.0    14260  ...        0      12    2008
# ...          ...          ...      ...  ...      ...     ...     ...
# 1455          60         62.0     7917  ...        0       8    2007
# 1456          20         85.0    13175  ...        0       2    2010
# 1457          70         66.0     9042  ...     2500       5    2010
# 1458          20         68.0     9717  ...        0       4    2010
# 1459          20         75.0     9937  ...        0       6    2008
#
# [1460 rows x 36 columns]
#      MSZoning Street Alley LotShape  ...  Fence MiscFeature SaleType SaleCondition
# ...

# %%
droppedStrColumns = ["Alley", "MiscFeature", "Fence", "PoolQC"]
droppedNumCols = ["GarageYrBlt"]

# %%
for col in droppedStrColumns:
  X_train_str.drop(col, axis=1, inplace=True)
  X_test_str.drop(col, axis=1, inplace=True)
  
for col in droppedNumCols:
  X_train_num.drop(col, axis=1, inplace=True)
  X_test_num.drop(col, axis=1, inplace=True)

# %%
print(X_train_num.head())
print(X_train_str.head())
print(X_test_num.head())
print(X_test_str.head())
# Out:
#    MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold
# 0          60         65.0     8450  ...        0       2    2008
# 1          20         80.0     9600  ...        0       5    2007
# 2          60         68.0    11250  ...        0       9    2008
# 3          70         60.0     9550  ...        0       2    2006
# 4          60         84.0    14260  ...        0      12    2008
#
# [5 rows x 35 columns]
#   MSZoning Street LotShape  ... PavedDrive SaleType SaleCondition
# 0       RL   Pave      Reg  ...          Y       WD        Normal
# 1       RL   Pave      Reg  ...          Y       WD        Normal
# 2       RL   Pave      IR1  ...          Y       WD        Normal
# 3       RL   Pave      IR1  ...          Y       WD       Abnorml
# 4       RL   Pave      IR1  ...          Y       WD        Normal
#
# [5 rows x 39 columns]
#    MSSubClass  LotFrontage  LotArea  ...  MiscVal  MoSold  YrSold
# ...

# %%
for col in X_train_str.columns:
  X_train_str[col].fillna(value="notAvailable", inplace=True)
  X_test_str[col].fillna(value="notAvailable", inplace=True)

X_train_num['LotFrontage'].fillna(value=X_train_num['LotFrontage'].median(), inplace=True)
X_test_num['LotFrontage'].fillna(value=X_test_num['LotFrontage'].median(), inplace=True)

for col in X_train_num.columns:
  X_train_num[col].fillna(value=X_train_num[col].mean(), inplace=True)
  X_test_num[col].fillna(value=X_test_num[col].mean(), inplace=True)

# %%
for col in X_train_str.columns:
  X_train_str[col].replace("Ex", 9, inplace=True)
  X_train_str[col].replace("Gd", 7, inplace=True)
  X_train_str[col].replace("TA", 5, inplace=True)
  X_train_str[col].replace("Fa", 3, inplace=True)
  X_train_str[col].replace("Po", 2, inplace=True)
  X_train_str[col].replace("notAvailable", 0, inplace=True)

  X_test_str[col].replace("Ex", 9, inplace=True)
  X_test_str[col].replace("Gd", 7, inplace=True)
  X_test_str[col].replace("TA", 5, inplace=True)
  X_test_str[col].replace("Fa", 3, inplace=True)
  X_test_str[col].replace("Po", 2, inplace=True)
  X_test_str[col].replace("notAvailable", 0, inplace=True)

# %%
X_train_str['ExterQual']
# Out:
# 0       7
# 1       5
# 2       7
# 3       5
# 4       7
#        ..
# 1455    5
# 1456    5
# 1457    9
# 1458    5
# 1459    7
# Name: ExterQual, Length: 1460, dtype: int64

# %%
checkNumericCols = []
checkStrCols = []
for col in X_train_str:
  if X_train_str[col].dtype == "int64" or X_train_str[col].dtype == "float64":
    checkNumericCols.append(col)
  else:
    checkStrCols.append(col)

# %%
print((checkNumericCols))
print((checkStrCols))
# Out:
# ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageQual', 'GarageCond']
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'GarageFinish', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
# check = ['Street', ]
# Condition1 and 2
# Exterior1 and 2

# BsmtExposure  BsmtFinType1 BsmtFinType2 GarageFinish
# PavedDrive

# %%
print(X_train_str['BsmtExposure'])
# Out:
# 0       No
# 1        7
# 2       Mn
# 3       No
# 4       Av
#         ..
# 1455    No
# 1456    No
# 1457    No
# 1458    Mn
# 1459    No
# Name: BsmtExposure, Length: 1460, dtype: object

# %%
X_train_str['BsmtExposure'].replace("Ex", 9, inplace=True)
X_train_str['BsmtExposure'].replace("Gd", 7, inplace=True)
X_train_str['BsmtExposure'].replace("Av", 5, inplace=True)
X_train_str['BsmtExposure'].replace("Mn", 3, inplace=True)
X_train_str['BsmtExposure'].replace("No", 2, inplace=True)
X_train_str['BsmtExposure'].replace("notAvailable", 0, inplace=True)

X_test_str['BsmtExposure'].replace("Ex", 9, inplace=True)
X_test_str['BsmtExposure'].replace("Gd", 7, inplace=True)
X_test_str['BsmtExposure'].replace("Av", 5, inplace=True)
X_test_str['BsmtExposure'].replace("Mn", 3, inplace=True)
X_test_str['BsmtExposure'].replace("No", 2, inplace=True)
X_test_str['BsmtExposure'].replace("notAvailable", 0, inplace=True)

# %%
X_train_str['BsmtFinType1'].replace("GLQ", 9, inplace=True)
X_train_str['BsmtFinType1'].replace("ALQ", 7, inplace=True)
X_train_str['BsmtFinType1'].replace("BLQ", 5, inplace=True)
X_train_str['BsmtFinType1'].replace("Rec", 4, inplace=True)
X_train_str['BsmtFinType1'].replace("LwQ", 3, inplace=True)
X_train_str['BsmtFinType1'].replace("Unf", 2, inplace=True)
X_train_str['BsmtFinType1'].replace("notAvailable", 0, inplace=True)

X_test_str['BsmtFinType1'].replace("GLQ", 9, inplace=True)
X_test_str['BsmtFinType1'].replace("ALQ", 7, inplace=True)
X_test_str['BsmtFinType1'].replace("BLQ", 5, inplace=True)
X_test_str['BsmtFinType1'].replace("Rec", 4, inplace=True)
X_test_str['BsmtFinType1'].replace("LwQ", 3, inplace=True)
X_test_str['BsmtFinType1'].replace("Unf", 2, inplace=True)
X_test_str['BsmtFinType1'].replace("notAvailable", 0, inplace=True)

# %%
 X_train_str['BsmtFinType2'].replace("GLQ", 9, inplace=True)
X_train_str['BsmtFinType2'].replace("ALQ", 7, inplace=True)
X_train_str['BsmtFinType2'].replace("BLQ", 5, inplace=True)
X_train_str['BsmtFinType2'].replace("Rec", 4, inplace=True)
X_train_str['BsmtFinType2'].replace("LwQ", 3, inplace=True)
X_train_str['BsmtFinType2'].replace("Unf", 2, inplace=True)
X_train_str['BsmtFinType2'].replace("notAvailable", 0, inplace=True)

X_test_str['BsmtFinType2'].replace("GLQ", 9, inplace=True)
X_test_str['BsmtFinType2'].replace("ALQ", 7, inplace=True)
X_test_str['BsmtFinType2'].replace("BLQ", 5, inplace=True)
X_test_str['BsmtFinType2'].replace("Rec", 4, inplace=True)
X_test_str['BsmtFinType2'].replace("LwQ", 3, inplace=True)
X_test_str['BsmtFinType2'].replace("Unf", 2, inplace=True)
X_test_str['BsmtFinType2'].replace("notAvailable", 0, inplace=True)

# %%
X_train_str['GarageFinish'].replace("Fin", 9, inplace=True)
X_train_str['GarageFinish'].replace("RFn", 6, inplace=True)
X_train_str['GarageFinish'].replace("Unf", 3, inplace=True)
X_train_str['GarageFinish'].replace("notAvailable", 0, inplace=True)

X_test_str['GarageFinish'].replace("Fin", 9, inplace=True)
X_test_str['GarageFinish'].replace("RFn", 6, inplace=True)
X_test_str['GarageFinish'].replace("Unf", 3, inplace=True)
X_test_str['GarageFinish'].replace("notAvailable", 0, inplace=True)

# %%
checkNumericCols = []
checkStrCols = []
for col in X_test_str:
  if X_test_str[col].dtype == "int64" or X_test_str[col].dtype == "float64":
    checkNumericCols.append(col)
  else:
    checkStrCols.append(col)

# %%
print((checkNumericCols))
print((checkStrCols))
# Out:
# ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC', 'KitchenQual', 'FireplaceQu', 'GarageFinish', 'GarageQual', 'GarageCond']
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
X_train_str_num = pd.DataFrame(X_train_str, columns=checkNumericCols)
X_test_str_num = pd.DataFrame(X_test_str, columns=checkNumericCols)

X_train_str_str = pd.DataFrame(X_train_str, columns=checkStrCols)
X_test_str_str = pd.DataFrame(X_test_str, columns=checkStrCols)

# %%
print(X_train_str_num.head())
print(X_train_str_str.head())
print(X_test_str_num.head())
print(X_test_str_str.head())
# Out:
#    ExterQual  ExterCond  BsmtQual  ...  GarageFinish  GarageQual  GarageCond
# 0          7          5         7  ...             6           5           5
# 1          5          5         7  ...             6           5           5
# 2          7          5         7  ...             6           5           5
# 3          5          5         5  ...             3           5           5
# 4          7          5         7  ...             6           5           5
#
# [5 rows x 13 columns]
#   MSZoning Street LotShape  ... PavedDrive SaleType SaleCondition
# 0       RL   Pave      Reg  ...          Y       WD        Normal
# 1       RL   Pave      Reg  ...          Y       WD        Normal
# 2       RL   Pave      IR1  ...          Y       WD        Normal
# 3       RL   Pave      IR1  ...          Y       WD       Abnorml
# 4       RL   Pave      IR1  ...          Y       WD        Normal
#
# [5 rows x 26 columns]
# ...

# %%
X_train_num = pd.concat([X_train_num, X_train_str_num], axis=1)
X_test_num = pd.concat([X_test_num, X_test_str_num], axis=1)

# %%
print(X_train_num.head())
print(X_test_num.head())
# Out:
#    MSSubClass  LotFrontage  LotArea  ...  GarageFinish  GarageQual  GarageCond
# 0          60         65.0     8450  ...             6           5           5
# 1          20         80.0     9600  ...             6           5           5
# 2          60         68.0    11250  ...             6           5           5
# 3          70         60.0     9550  ...             3           5           5
# 4          60         84.0    14260  ...             6           5           5
#
# [5 rows x 48 columns]
#    MSSubClass  LotFrontage  LotArea  ...  GarageFinish  GarageQual  GarageCond
# 0          20         80.0    11622  ...             3           5           5
# 1          20         81.0    14267  ...             3           5           5
# 2          60         74.0    13830  ...             9           5           5
# 3          60         78.0     9978  ...             9           5           5
# 4         120         43.0     5005  ...             6           5           5
#
# ...

# %%
X_train_str_str.tail()
# Out:
#      MSZoning Street LotShape  ... PavedDrive SaleType SaleCondition
# 1455       RL   Pave      Reg  ...          Y       WD        Normal
# 1456       RL   Pave      Reg  ...          Y       WD        Normal
# 1457       RL   Pave      Reg  ...          Y       WD        Normal
# 1458       RL   Pave      Reg  ...          Y       WD        Normal
# 1459       RL   Pave      Reg  ...          Y       WD        Normal
#
# [5 rows x 26 columns]

# %%
X_train_str_str.head()
# Out:
#   MSZoning Street LotShape  ... PavedDrive SaleType SaleCondition
# 0       RL   Pave      Reg  ...          Y       WD        Normal
# 1       RL   Pave      Reg  ...          Y       WD        Normal
# 2       RL   Pave      IR1  ...          Y       WD        Normal
# 3       RL   Pave      IR1  ...          Y       WD       Abnorml
# 4       RL   Pave      IR1  ...          Y       WD        Normal
#
# [5 rows x 26 columns]

# %%
X_encoder = pd.concat([X_train_str_str, X_test_str_str])

# %%
X_encoder.shape
# Out:
# (2919, 188)

# %%
X_encoded_train = X_encoder.iloc[:1460, :]
X_encoded_test = X_encoder.iloc[1460: , :]

# %%
X_encoded_train.tail()
# Out:
#       MSZoning_0  MSZoning_C (all)  ...  SaleCondition_Normal  SaleCondition_Partial
# 1455           0                 0  ...                     1                      0
# 1456           0                 0  ...                     1                      0
# 1457           0                 0  ...                     1                      0
# 1458           0                 0  ...                     1                      0
# 1459           0                 0  ...                     1                      0
#
# [5 rows x 188 columns]

# %%
X_encoded_test.tail()
# Out:
#       MSZoning_0  MSZoning_C (all)  ...  SaleCondition_Normal  SaleCondition_Partial
# 1454           0                 0  ...                     1                      0
# 1455           0                 0  ...                     0                      0
# 1456           0                 0  ...                     0                      0
# 1457           0                 0  ...                     1                      0
# 1458           0                 0  ...                     1                      0
#
# [5 rows x 188 columns]

# %%
print(str(X_encoder.columns))
# Out:
# Index(['MSZoning_0', 'MSZoning_C (all)', 'MSZoning_FV', 'MSZoning_RH',
#        'MSZoning_RL', 'MSZoning_RM', 'Street_Grvl', 'Street_Pave',
#        'LotShape_IR1', 'LotShape_IR2',
#        ...
#        'SaleType_ConLw', 'SaleType_New', 'SaleType_Oth', 'SaleType_WD',
#        'SaleCondition_Abnorml', 'SaleCondition_AdjLand',
#        'SaleCondition_Alloca', 'SaleCondition_Family', 'SaleCondition_Normal',
#        'SaleCondition_Partial'],
#       dtype='object', length=188)

# %%
X_encoder.head()
# Out:
#    MSZoning_0  MSZoning_C (all)  ...  SaleCondition_Normal  SaleCondition_Partial
# 0           0                 0  ...                     1                      0
# 1           0                 0  ...                     1                      0
# 2           0                 0  ...                     1                      0
# 3           0                 0  ...                     0                      0
# 4           0                 0  ...                     1                      0
#
# [5 rows x 188 columns]

# %%
X_train = pd.concat([X_train_num, X_encoded_train], axis=1)
X_test = pd.concat([X_test_num, X_encoded_test], axis=1)

# %%
X_train.shape
# Out:
# (1460, 236)

# %%
X_test.shape
# Out:
# (1459, 236)

# %%
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-73020798007e> in <module>()
# ----> 1 X_train.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
X_test.head()
# Out:
#    MSSubClass  LotFrontage  ...  SaleCondition_Normal  SaleCondition_Partial
# 0          20         80.0  ...                     1                      0
# 1          20         81.0  ...                     1                      0
# 2          60         74.0  ...                     1                      0
# 3          60         78.0  ...                     1                      0
# 4         120         43.0  ...                     1                      0
#
# [5 rows x 236 columns]

# %%
X_train=X_train.values
X_test=X_test.values

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 0.07337496 -0.22087509 -0.20714171 ... -0.11785113  0.4676514
#   -0.30599503]
#  [-0.87256276  0.46031974 -0.09188637 ... -0.11785113  0.4676514
#   -0.30599503]
#  [ 0.07337496 -0.08463612  0.07347998 ... -0.11785113  0.4676514
#   -0.30599503]
#  ...
#  [ 0.30985939 -0.1754621  -0.14781027 ... -0.11785113  0.4676514
#   -0.30599503]
#  [-0.87256276 -0.08463612 -0.08016039 ... -0.11785113  0.4676514
#   -0.30599503]
#  [-0.87256276  0.23325479 -0.05811155 ... -0.11785113  0.4676514
#   -0.30599503]]

# %%
y_train.head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
y_train = y_train.values

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components = 15, kernel="rbf")
X_train = kpca.fit_transform(X_train)
X_test = kpca.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 256)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=256, verbose=0, warm_start=False)

# %%
y_pred = regressor.predict(X_test)

# %%
print(y_pred)
# Out:
# [118990.  183309.8 182400.  ... 148315.  106925.  205614. ]

# %%
submit = pd.DataFrame({'Id': testset.iloc[:, 0].values, 'SalePrice': y_pred})
print(submit)
# Out:
#         Id  SalePrice
# 0     1461   118990.0
# 1     1462   183309.8
# 2     1463   182400.0
# 3     1464   185184.0
# 4     1465   203164.0
# ...    ...        ...
# 1454  2915    95690.0
# 1455  2916   105140.0
# 1456  2917   148315.0
# 1457  2918   106925.0
# 1458  2919   205614.0
#
# [1459 rows x 2 columns]

# %%
submit.to_csv('HousePrice.csv', index=False)
